# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import re
# %matplotlib inline

# %%
pd.read_csv('unemployment_data.csv')
# Out:
#      country_name                    indicator_name     sex age_group  \
# 0     Afghanistan  Unemployment rate by sex and age  Female     15-24
# 1     Afghanistan  Unemployment rate by sex and age  Female       25+
# 2     Afghanistan  Unemployment rate by sex and age  Female  Under 15
# 3     Afghanistan  Unemployment rate by sex and age    Male     15-24
# 4     Afghanistan  Unemployment rate by sex and age    Male       25+
# ...           ...                               ...     ...       ...
# 1129     Zimbabwe  Unemployment rate by sex and age  Female       25+
# 1130     Zimbabwe  Unemployment rate by sex and age  Female  Under 15
# 1131     Zimbabwe  Unemployment rate by sex and age    Male     15-24
# 1132     Zimbabwe  Unemployment rate by sex and age    Male       25+
# 1133     Zimbabwe  Unemployment rate by sex and age    Male  Under 15
#
#      age_categories    2014    2015    2016    2017    2018    2019    2020  \
# ...

# %%
global_unemployment=pd.read_csv('unemployment_data.csv')

# %%
global_unemployment
# Out:
#      country_name                    indicator_name     sex age_group  \
# 0     Afghanistan  Unemployment rate by sex and age  Female     15-24
# 1     Afghanistan  Unemployment rate by sex and age  Female       25+
# 2     Afghanistan  Unemployment rate by sex and age  Female  Under 15
# 3     Afghanistan  Unemployment rate by sex and age    Male     15-24
# 4     Afghanistan  Unemployment rate by sex and age    Male       25+
# ...           ...                               ...     ...       ...
# 1129     Zimbabwe  Unemployment rate by sex and age  Female       25+
# 1130     Zimbabwe  Unemployment rate by sex and age  Female  Under 15
# 1131     Zimbabwe  Unemployment rate by sex and age    Male     15-24
# 1132     Zimbabwe  Unemployment rate by sex and age    Male       25+
# 1133     Zimbabwe  Unemployment rate by sex and age    Male  Under 15
#
#      age_categories    2014    2015    2016    2017    2018    2019    2020  \
# ...

# %%
global_unemployment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1134 entries, 0 to 1133
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country_name    1134 non-null   object
#  1   indicator_name  1134 non-null   object
#  2   sex             1134 non-null   object
#  3   age_group       1134 non-null   object
#  4   age_categories  1134 non-null   object
#  5   2014            1134 non-null   float64
#  6   2015            1134 non-null   float64
#  7   2016            1134 non-null   float64
#  8   2017            1134 non-null   float64
#  9   2018            1134 non-null   float64
#  10  2019            1134 non-null   float64
#  11  2020            1134 non-null   float64
#  12  2021            1134 non-null   float64
#  13  2022            1128 non-null   float64
#  14  2023            1122 non-null   float64
#  15  2024            1122 non-null   float64
# dtypes: float64(11), object(5)
# ...

# %%
global_unemployment.shape
# Out:
# (1134, 16)

# %%
data = pd.read_csv('unemployment_data.csv' , index_col='country_name')

# %%
data
# Out:
#                                 indicator_name     sex age_group  \
# country_name
# Afghanistan   Unemployment rate by sex and age  Female     15-24
# Afghanistan   Unemployment rate by sex and age  Female       25+
# Afghanistan   Unemployment rate by sex and age  Female  Under 15
# Afghanistan   Unemployment rate by sex and age    Male     15-24
# Afghanistan   Unemployment rate by sex and age    Male       25+
# ...                                        ...     ...       ...
# Zimbabwe      Unemployment rate by sex and age  Female       25+
# Zimbabwe      Unemployment rate by sex and age  Female  Under 15
# Zimbabwe      Unemployment rate by sex and age    Male     15-24
# Zimbabwe      Unemployment rate by sex and age    Male       25+
# Zimbabwe      Unemployment rate by sex and age    Male  Under 15
#
#              age_categories    2014    2015    2016    2017    2018    2019  \
# country_name
# Afghanistan           Youth  13.340  15.974  18.570  21.137  20.649  20.154
# ...

# %%
global_unemployment = pd.read_csv('unemployment_data.csv' , index_col='country_name')

# %%
global_unemployment
# Out:
#                                 indicator_name     sex age_group  \
# country_name
# Afghanistan   Unemployment rate by sex and age  Female     15-24
# Afghanistan   Unemployment rate by sex and age  Female       25+
# Afghanistan   Unemployment rate by sex and age  Female  Under 15
# Afghanistan   Unemployment rate by sex and age    Male     15-24
# Afghanistan   Unemployment rate by sex and age    Male       25+
# ...                                        ...     ...       ...
# Zimbabwe      Unemployment rate by sex and age  Female       25+
# Zimbabwe      Unemployment rate by sex and age  Female  Under 15
# Zimbabwe      Unemployment rate by sex and age    Male     15-24
# Zimbabwe      Unemployment rate by sex and age    Male       25+
# Zimbabwe      Unemployment rate by sex and age    Male  Under 15
#
#              age_categories    2014    2015    2016    2017    2018    2019  \
# country_name
# Afghanistan           Youth  13.340  15.974  18.570  21.137  20.649  20.154
# ...

# %%
global_unemployment.isnull().sum()
# Out:
# indicator_name     0
# sex                0
# age_group          0
# age_categories     0
# 2014               0
# 2015               0
# 2016               0
# 2017               0
# 2018               0
# 2019               0
# 2020               0
# 2021               0
# 2022               6
# 2023              12
# 2024              12
# dtype: int64

# %%
global_unemployment.describe()
# Out:
#               2014         2015         2016         2017         2018  \
# count  1134.000000  1134.000000  1134.000000  1134.000000  1134.000000
# mean     11.387800    11.272444    11.122963    10.863516    10.516499
# std      11.119002    10.915942    10.742947    10.640980    10.527773
# min       0.027000     0.034000     0.038000     0.035000     0.044000
# 25%       3.933500     3.993500     3.945250     3.747500     3.672750
# 50%       7.697500     7.547500     7.504500     7.140500     6.706000
# 75%      15.050750    14.766250    14.467500    14.142000    13.343000
# max      74.485000    74.655000    74.720000    75.416000    76.395000
#
#               2019         2020         2021         2022         2023  \
# count  1134.000000  1134.000000  1134.000000  1128.000000  1122.000000
# mean     10.311452    11.851285    11.422645    10.340361     9.985181
# std      10.297952    11.231580    10.873412    10.264810     9.987778
# ...

# %%
global_unemployment['age_group'].value_counts()
# Out:
# age_group
# 15-24       378
# 25+         378
# Under 15    378
# Name: count, dtype: int64

# %%
global_unemployment['age_categories'].value_counts()
# Out:
# age_categories
# Youth       378
# Adults      378
# Children    378
# Name: count, dtype: int64

# %%
Highest_unemployment= global_unemployment.groupby(['age_categories'])['2014'].agg(['sum'])
Highest_unemployment.sort_values(by = 'sum' , ascending = False)
# Out:
#                      sum
# age_categories
# Youth           7126.851
# Children        3237.417
# Adults          2549.497

# %%
global_unemployment['sex'].value_counts()
# Out:
# sex
# Female    567
# Male      567
# Name: count, dtype: int64

# %%
global_unemployment.plot
